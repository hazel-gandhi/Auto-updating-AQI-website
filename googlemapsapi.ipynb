# %%
import requests
import time 
# Your Google Maps API key
API_KEY = "AIzaSyCrQdbLQ734osgxi5GspLDdmh3CsY9tJYQ"

city_coords = []

# List of cities
cities = ['Agartala','Agra','Ahmedabad','Ahmednagar','Aizawl','Ajmer','Akola','Alwar','Amaravati','Ambala','Amravati', 'Amritsar', 'Anantapur',
 'Angul', 'Araria', 'Ariyalur','Arrah','Asansol', 'Aurangabad, Bihar','Aurangabad, Maharashtra','Baddi','Badlapur','Bagalkot','Baghpat',
 'Bahadurgarh','Balasore','Banswara','Baran','Barbil','Bareilly','Barmer','Bathinda','Begusarai','Belapur','Belgaum','Bengaluru','Bettiah',
 'Bhagalpur','Bharatpur','Bhilai','Bhilwara','Bhiwadi','Bhiwandi','Bhiwani','Bhopal','Bhubaneswar','Bidar','Bihar Sharif','Bikaner',
 'Bilaspur','Bileipada','Boisar','Brajrajnagar','Bulandshahr',
 'Bundi',
 'Buxar',
 'Byasanagar',
 'Byrnihat',
 'Chamarajanagar',
 'Chandigarh',
 'Chandrapur',
 'Charkhi Dadri',
 'Chengalpattu',
 'Chennai',
 'Chhal',
 'Chikkaballapur',
 'Chikkamagaluru',
 'Chittoor',
 'Chittorgarh',
 'Churu',
 'Coimbatore',
 'Cuddalore',
 'Cuttack',
 'Damoh',
 'Dausa',
 'Davanagere',
 'Dehradun',
 'Delhi',
 'Dewas',
 'Dhanbad',
 'Dharuhera',
 'Dharwad',
 'Dholpur',
 'Dhule',
 'Dungarpur',
 'Durgapur',
 'Faridabad',
 'Fatehabad',
 'Firozabad',
 'Gadag',
 'Gandhinagar',
 'Gaya',
 'Ghaziabad',
 'Gorakhpur',
 'Greater Noida',
 'Gummidipoondi',
 'Gurugram',
 'Guwahati',
 'Gwalior',
 'Hajipur',
 'Haldia',
 'Hapur',
 'Hassan',
 'Haveri',
 'Hisar',
 'Howrah',
 'Hubballi',
 'Hyderabad',
 'Imphal',
 'Indore',
 'Jabalpur',
 'Jaipur',
 'Jaisalmer',
 'Jalandhar',
 'Jalgaon',
 'Jalna',
 'Jalore',
 'Jhalawar',
 'Jhansi',
 'Jhunjhunu',
 'Jind',
 'Jodhpur',
 'Kaithal',
 'Kalaburagi',
 'Kalyan',
 'Kanchipuram',
 'Kannur',
 'Kanpur',
 'Karauli',
 'Karnal',
 'Karur',
 'Karwar',
 'Kashipur',
 'Katihar',
 'Katni',
 'Keonjhar',
 'Khanna',
 'Khurja',
 'Kohima',
 'Kolar',
 'Kolhapur',
 'Kolkata',
 'Kollam',
 'Koppal',
 'Korba',
 'Kota',
 'Kunjemura',
 'Kurukshetra',
 'Latur',
 'Lucknow',
 'Ludhiana',
 'Madikeri',
 'Mahad',
 'Maihar',
 'Malegaon',
 'Mandi Gobindgarh',
 'Mandideep',
 'Mandikhera',
 'Manesar',
 'Mangalore',
 'Manguraha',
 'Meerut',
 'Mira-Bhayandar',
 'Moradabad',
 'Motihari',
 'Mumbai',
 'Munger',
 'Muzaffarnagar',
 'Muzaffarpur',
 'Mysuru',
 'Nagaon',
 'Nagaur',
 'Nagpur',
 'Naharlagun',
 'Nashik',
 'Navi Mumbai',
 'Noida',
 'Pali',
 'Palwal',
 'Panchkula',
 'Panipat',
 'Parbhani',
 'Patiala',
 'Patna',
 'Pimpri-Chinchwad',
 'Pithampur',
 'Pratapgarh',
 'Prayagraj',
 'Puducherry',
 'Pudukottai',
 'Pune',
 'Purnia',
 'Raipur',
 'Rairangpur',
 'Rajamahendravaram',
 'Rajgir',
 'Rajsamand',
 'Ranipet',
 'Ratlam',
 'Rishikesh',
 'Rohtak',
 'Rourkela',
 'Rupnagar',
 'Sagar',
 'Saharsa',
 'Samastipur',
 'Sangli',
 'Sasaram',
 'Satna',
 'Sawai Madhopur',
 'Shillong',
 'Shivamogga',
 'Sikar',
 'Silchar',
 'Siliguri',
 'Singrauli',
 'Sirohi',
 'Sirsa',
 'Sivasagar',
 'Siwan',
 'Solapur',
 'Sonipat',
 'Sri Ganganagar',
 'Suakati',
 'Surat',
 'Talcher',
 'Tensa',
 'Thane',
 'Thanjavur',
 'Thiruvananthapuram',
 'Thoothukudi',
 'Thrissur',
 'Tirupati',
 'Tonk',
 'Tumakuru',
 'Udaipur',
 'Ujjain',
 'Ulhasnagar',
 'Vapi',
 'Varanasi',
 'Vatva',
 'Vellore',
 'Vijayapura',
 'Vijayawada',
 'Virar',
 'Virudhunagar',
 'Vrindavan',
 'Yadgir',
 'Yamuna Nagar']


# Base URL for the Geocoding API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# Dictionary to store results
city_coordinates = {}

for city in cities:
    # Construct the request URL
    params = {
        "address": city,
        "key": API_KEY
    }
    
    # Send the request
    response = requests.get(base_url, params=params)
    data = response.json()
    
    # Check if the response contains results
    if data["status"] == "OK":
        # Extract latitude and longitude
        location = data["results"][0]["geometry"]["location"]
        latitude = location["lat"]
        longitude = location["lng"]

        # Append the data to the list
        city_coords.append({"city": city, "lats": latitude, "longs": longitude})
    else:
        print(f"Error fetching data for {city}: {data['status']}")
    
    # Rate limit to avoid exceeding API quotas
    time.sleep(1)

# Print the final list of dictionaries
print(city_coords)
# Out:
# Error fetching data for Badlapur: ZERO_RESULTS
# Error fetching data for Baran: ZERO_RESULTS
# Error fetching data for Chhal: ZERO_RESULTS
# Error fetching data for Tensa: ZERO_RESULTS
# Error fetching data for Virar: ZERO_RESULTS
# ...

# %%
len(city_coords)
# Out:
# 244

# %%
import pandas as pd
df = pd.DataFrame(city_coords)
df
# Out:
#              city       lats      longs
# 0        Agartala  23.831457  91.286778
# 1            Agra  27.176670  78.008074
# 2       Ahmedabad  23.022505  72.571362
# 3      Ahmednagar  19.094829  74.747979
# 4          Aizawl  23.730718  92.717311
# ..            ...        ...        ...
# 239    Vijayawada  16.506174  80.648015
# 240  Virudhunagar   9.568012  77.962443
# 241     Vrindavan  27.565009  77.659339
# 242        Yadgir  16.762552  77.144225
# 243  Yamuna Nagar  30.129048  77.267390
#
# [244 rows x 3 columns]

# %%
new_rows = [
    {"city": "Badlapur", "lats": 19.166784, "longs": 73.236794},
    {"city": "Baran", "lats": 25.101145, "longs": 76.513161},
    {"city": "Chhal", "lats": 22.128320, "longs": 83.116230},
    {"city": "Tensa", "lats": 21.872885, "longs": 85.164911},
    {"city": "Virar", "lats": 19.465622, "longs": 72.806099}
]

# Add rows to the DataFrame
df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)

print(df)
# Out:
#            city       lats      longs
# 0      Agartala  23.831457  91.286778
# 1          Agra  27.176670  78.008074
# 2     Ahmedabad  23.022505  72.571362
# 3    Ahmednagar  19.094829  74.747979
# 4        Aizawl  23.730718  92.717311
# ..          ...        ...        ...
# 246    Badlapur  19.166784  73.236794
# 247       Baran  25.101145  76.513161
# 248       Chhal  22.128320  83.116230
# 249       Tensa  21.872885  85.164911
# 250       Virar  19.465622  72.806099
#
# [251 rows x 3 columns]

# %%
df.drop_duplicates()
# Out:
#            city       lats      longs
# 0      Agartala  23.831457  91.286778
# 1          Agra  27.176670  78.008074
# 2     Ahmedabad  23.022505  72.571362
# 3    Ahmednagar  19.094829  74.747979
# 4        Aizawl  23.730718  92.717311
# ..          ...        ...        ...
# 244    Badlapur  19.166784  73.236794
# 245       Baran  25.101145  76.513161
# 248       Chhal  22.128320  83.116230
# 249       Tensa  21.872885  85.164911
# 250       Virar  19.465622  72.806099
#
# [249 rows x 3 columns]

# %%
df.to_csv("city_coords.csv", index=False)
