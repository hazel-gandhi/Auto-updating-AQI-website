# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)

# %%
page = await browser.new_page()

# %%
await page.goto("https://airquality.cpcb.gov.in/AQI_India/", timeout=40000)
# Out:
# <Response url='https://airquality.cpcb.gov.in/AQI_India/' request=<Request url='https://airquality.cpcb.gov.in/AQI_India/' method='GET'>>

# %%
html = await page.content()
html
# Out:
# '<!DOCTYPE html><html lang="en" class=" -webkit-"><head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <title>National Air Quality Index</title>\n  <!-- Bootstrap -->\n  <style media="" data-href="assets/stylesheets/bootstrap.min.css">@import url("https://fonts.googleapis.com/css?family=Lato:400,700,400italic");/*!\r\n * bootswatch v3.3.1+2\r\n * Homepage: http://bootswatch.com\r\n * Copyright 2012-2014 Thomas Park\r\n * Licensed under MIT\r\n * Based on Bootstrap\r\n*//*! normalize.css v3.0.2 | MIT License | git.io/normalize */html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}audio,canvas,progress,video{display:inline-block;vertical-align:baseline}audio:not([controls]){display:none;height:0}[hidden],template{display:none}a
# ...

# %%
await page.get_by_placeholder("Enter Captcha Here").fill("JQBTON")

# %%
await page.get_by_role("button", name="Verify").click()

# %%
import io
import time
import string

# %%
await page.get_by_label("State").select_option('Andhra Pradesh')
await page.get_by_label("City").select_option('Amaravati')
# await page.get_by_label("Station").select_option('Secretariat, Amaravati - APPCB')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 await page.get_by_label("State").select_option('Andhra Pradesh')
#       2 await page.get_by_label("City").select_option('Amaravati')
#       3 # await page.get_by_label("Station").select_option('Secretariat, Amaravati - APPCB')
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/playwright/async_api/_generated.py:17203, in Locator.select_option(self, value, index, label, element, timeout, no_wait_after, force)
#   17126 async def select_option(
#   17127     self,
#   17128     value: typing.Optional[typing.Union[str, typing.Sequence[str]]] = None,
#    (...)
#   17137     force: typing.Optional[bool] = None
#   17138 ) -> typing.List[str]:
#   17139     """Locator.select_option
#   17140
#   17141     Selects option or options in `<select>`.
#    (...)
#   17199     List[str]
# ...

# %%
critic_info['Name']:
