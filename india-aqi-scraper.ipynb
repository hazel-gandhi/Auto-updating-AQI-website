# %% [markdown]
# ## Auto-updating AQI website
# #### This website scrapes the data from [India's Pollution Control Board](https://cpcb.nic.in/AQI_Bulletin.php) to map the daily AQIs of major cities

# %%
## Imports
from bs4 import BeautifulSoup
import requests
import urllib3
from img2table.document import PDF
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from datetime import datetime
import time

# %% [markdown]
# ### Scraping the website that has my pdf's url and making it grab the first pdf (the one with the latest AQI) every day

# %%
url = "https://cpcb.nic.in/AQI_Bulletin.php"
raw_html = requests.get(url, verify=False).content
soup_doc = BeautifulSoup(raw_html, 'html.parser')
soup_doc.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="text/html;charset=utf-8" http-equiv="Content-Type" name="Referrer-Policy" value="no-referrer | same-origin"/>\n  <!--meta charset="utf-8"-->\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <!--meta charset="utf-8"-->\n  <meta content="cpcb|central pollution control board,aqi,AQI,AQI Delhi,cpcb.nic.in,https://cpcb.nic.in,CPCB,ccb,pollution board,air quality index,cpcb delhi,cpcbmoefcc,pollution control,cpcb,CPCB Water, CPCB Air, CPCB Noise, CPCB Waste, Air Quality Data, Air Pollution control, Air Quality Trends, Water Quality Data, Water Pollution control, Water Quality Trends, Noise Pollution control, Industrial Pollution, CEPI, Critically polluted Industries, Noise Monitoring Data, Environmental Standard, Real time data water air noise,  Annual Reports, Publication, Deepawali, Ambient, SPCB, Kids Corner, Scanned Report, on demand publication, bibliography, glossary, major activities, TSDFs, TSDF, Treatment, Storage, and Disposal Facilities, bio-medical waste, e-waste, green energy,hazardaous waste, industrial waste, bhuvan, Industrial Pollution, cpcb,Pollution Control,Water Pollution,Noise Pollution, Air Pollution,Water Quality Criteria,Industry effluent standards,Noise Limits for Vehicles,Noise Limits for Generator Set" name="keywords">\n   <meta content="CPCB | Central Pollution Control Board, Ministry of Environment, Forest and Climate Change, Water Pollution, Air Pollution, Noise Pollution, Waste Management" name="description"/>\n   <meta content="CPCB | Central Pollution Control Board , Ministry of Environment, Forest and Climate Change, Environmental Acts &amp; Rules, Environment Protection, Water Pollution, Air Pollution, Noise Pollution, Waste Management" name="topic"/>\n   <meta content="Central Pollution, Air Pollution,Water Pollution, Ministry of Environment, Forest and Climate Change, Environmental Acts &amp; Rules, Environment Protection, Noise Pollution, Waste Management " name="subject"/>\n   <meta content="Central Pollution,Environment Protection, Water Pollution, Air Pollution, Noise Pollution, Waste Management Ministry of Environment, Forest and Climate Change, Environmental Acts &amp; Rules, " name="abstract"/>\n   <meta content="Central Pollution, Air Pollution, Noise Pollution, Waste Management Ministry of Environment, Forest and Climate Change, Environmental Acts &amp; Rules, Environment Protection, Water Pollution, " name="key-phrases"/>\n   <meta content="Central Pollution,Environmental Acts &amp; Rules, Environment Protection, Water Pollution, Air Pollution, Noise Pollution, Waste Management Ministry of Environment, Forest and Climate Change, " name="Pollution">\n    <!--meta name=\'robots\' content=\'index, follow\'/-->\n    <meta content="CPCB" name="copyright">\n     <meta content="CPCB" name="owner">\n      <meta content="en" http-equiv="content-language">\n       <meta content="global" name="distribution">\n        <meta content="general" name="rating">\n         <meta content="width=device-width, initial-scale=1" name="viewport"/>\n         <meta content="no-referrer" name="referrer"/>\n         <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n         <meta content="LZKMnqL0by20OvXEYksj7BlBSuc0HUbSFwnV7I7mtFs" name="google-site-verification">\n          <!--title> Central Pollution Control Board | Ministry of Environment, Forest and Climate Change, Government of India </title-->\n          <title>\n           CPCB | Central Pollution Control Board\n          </title>\n          <link href="https://cpcb.nic.in/images/glpi.jpg" rel="icon"/>\n          <style>\n           @import url("https://cpcb.nic.in/css/main123.css");\n          </style>\n          <link href="https://cpcb.nic.in/asset/slider/css/js-image-slider.css" rel="stylesheet" type="text/css"/>\n          <script src="https://cpcb.nic.in/asset/slider/js/js-image-slider.js">\n          </script>\n          <!--<link href="https://cpcb.nic. ...

# %%
# Grabbing first pdf
pdfs = soup_doc.find('ol').find('li').find('a')['href']
pdfs
# Out:
# 'https://cpcb.nic.in/displaypdf.php?id=RG93bmxvYWRzL0FRSV9CdWxsZXRpbl8yMDI2MDEyOS5wZGY='

# %% [markdown]
# ### Naming the file according to the date on which it was uploaded so I know which pdf is being scraped

# %%
url = pdfs

current_date = datetime.now()

date_string = current_date.strftime("%Y-%m-%d")

file_name = f"document_{date_string}.pdf"

response = requests.get(url, stream=True, verify=False)

with open(file_name, "wb") as file:
    for chunk in response.iter_content(chunk_size=8192):
        file.write(chunk)

# %% [markdown]
# ### After scraping the url that has the pdf and downloading it, I'll import it back again to scrape the pdf using Natural PDF

# %%
pdf = PDF(file_name)

# %%
#Extracting tables, seeing how many are there
extracted_tables = pdf.extract_tables()

print(f"Found {len(extracted_tables)} tables")
# Out:
# Found 14 tables

# %%
extracted_tables[0][0].df #the actual data is nested in a structure like this
# Out:
#        0                          1             2             3  \
# 0   S.No                       City   Air Quality  Index\nValue
# 1      1                       Agra      Moderate           107
# 2      2                  Ahmedabad      Moderate           124
# 3      3                 Ahmednagar  Satisfactory            82
# 4      4                     Aizawl  Satisfactory            56
# 5      5                      Ajmer      Moderate           114
# 6      6                      Akola  Satisfactory            72
# 7      7                      Alwar      Moderate           123
# 8      8                  Amaravati          Poor           227
# 9      9                     Ambala          Good            50
# 10    10                   Amravati  Satisfactory            94
# 11    11                   Amritsar      Moderate           114
# 12    12                  Anantapur  Satisfactory            78
# 13    13                      Angul     Very Poor           310
# 14    14                 Ankleshwar  Satisfactory            98
# 15    15                     Araria      Moderate           114
# 16    16                      Arrah  Satisfactory            53
# 17    17                    Asansol      Moderate           170
# 18    18  Aurangabad\n(Maharashtra)  Satisfactory            93
# 19    19                      Baddi      Moderate           128
# 20    20                   Badlapur      Moderate           112
#
#                       4                                               5
# 0   Prominent Pollutant  No. of Stations\nParticipated/\nTotal Stations
# 1                  PM10                                             5/6
# 2             PM10, NO2                                             8/9
# 3                  PM10                                             1/1
# 4                 PM2.5                                             1/1
# 5                  PM10                                             1/1
# 6                  PM10                                             1/1
# 7                  PM10                                             1/1
# 8                 PM2.5                                             1/1
# 9                  PM10                                             1/1
# 10                 PM10                                             2/2
# 11                 PM10                                             1/1
# 12                PM2.5                                             1/1
# 13                   O3                                             1/1
# 14                 PM10                                             1/1
# 15                PM2.5                                             1/1
# 16                   CO                                             1/1
# 17                PM2.5                                             4/4
# 18          PM10, PM2.5                                             3/3
# 19                 PM10                                             1/1
# 20                 PM10                                             1/1

# %% [markdown]
# ### Looping through all the pages, making each page a df, then joining them all together into `df`

# %%
import pandas as pd

dfs = []

for page in extracted_tables.values():
    for table in page:
        # Add it to the list
        dfs.append(table.df)

df = pd.concat(dfs, ignore_index=True)
df.head()
# Out:
#       0           1             2             3                    4  \
# 0  S.No        City   Air Quality  Index\nValue  Prominent Pollutant
# 1     1        Agra      Moderate           107                 PM10
# 2     2   Ahmedabad      Moderate           124            PM10, NO2
# 3     3  Ahmednagar  Satisfactory            82                 PM10
# 4     4      Aizawl  Satisfactory            56                PM2.5
#
#                                                 5
# 0  No. of Stations\nParticipated/\nTotal Stations
# 1                                             5/6
# 2                                             8/9
# 3                                             1/1
# 4                                             1/1

# %% [markdown]
# ### Data cleaning

# %%
#Making the first row the header
df.columns = df.loc[0] 
df = df.drop(index=0)

#Each page of the pdf has the headers again and again, I only want them on the first page. Removing them from the rest of the dataframe
df_filtered = df[~df['S.No'].str.contains('S.No', case=False, na=False)] 

#Removing last few unnecessary lines from the df
df = df_filtered[:-7]

# %% [markdown]
# ### Making a list of cities to use in the geocoding API and get their lats and longs for mapping. This will be exported as csv and used in a separate notebook, `geocoding.ipynb`, to get each city's coordinates

# %%
cities = df[['City']]
cities.to_csv("cities.csv", index=False)

# %% [markdown]
# ### Reading in the csv I made in the `geocoding.ipynb` here again

# %%
new_df = pd.read_csv("city_coords.csv")
new_df = new_df.rename(columns={"city" : "City"})
new_df
# Out:
#               City        Lat        Lng
# 0             Agra  27.176670  78.008074
# 1        Ahmedabad  23.022505  72.571362
# 2       Ahmednagar  19.094829  74.747979
# 3           Aizawl  23.730718  92.717311
# 4            Ajmer  26.449895  74.639916
# ..             ...        ...        ...
# 237          Virar  19.456360  72.792461
# 238  Visakhapatnam  17.697380  83.299025
# 239      Vrindavan  27.565009  77.659339
# 240         Yadgir  16.748739  77.130872
# 241   Yamuna Nagar  30.129048  77.267390
#
# [242 rows x 3 columns]

# %%
### Merging the files with the original AQI dfs, so it has Cities and Coordinates

# %%
merged_df = pd.merge(df, new_df, on="City", how="left")

#Renaming the df for easier use
df = merged_df

#Verifying count of cities
len(df['City'])
# Out:
# 242

# %% [markdown]
# ### Saving this as a new csv. This one will be used to power the datawrapper chart.

# %%
df.to_csv('final_aqi.csv', index=False)
